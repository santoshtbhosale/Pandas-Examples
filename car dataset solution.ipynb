# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#     Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0    STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1    Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2    Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3    Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4    AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US
# ..                                                 ...
# 402  Ford Mustang GL;27.0;4;140.0;86.00;2790.;15.6;...
# 403  Volkswagen Pickup;44.0;4;97.00;52.00;2130.;24....
# 404  Dodge Rampage;32.0;4;135.0;84.00;2295.;11.6;82;US
# 405    Ford Ranger;28.0;4;120.0;79.00;2625.;18.6;82;US
# 406     Chevy S-10;31.0;4;119.0;82.00;2720.;19.4;82;US
#
# [407 rows x 1 columns]

# %%
a = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[0])
df.insert(0,'Car',a)

# %%
df.head()
# Out:
#                          Car  \
# 0                     STRING
# 1  Chevrolet Chevelle Malibu
# 2          Buick Skylark 320
# 3         Plymouth Satellite
# 4              AMC Rebel SST
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[1])
df.insert(1,'MPG',b)
df.head()
# Out:
#                          Car     MPG  \
# 0                     STRING  DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0
# 2          Buick Skylark 320    15.0
# 3         Plymouth Satellite    18.0
# 4              AMC Rebel SST    16.0
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[2])
df.insert(2,'Cylinders',b)
df.head()
# Out:
#                          Car     MPG Cylinders  \
# 0                     STRING  DOUBLE       INT
# 1  Chevrolet Chevelle Malibu    18.0         8
# 2          Buick Skylark 320    15.0         8
# 3         Plymouth Satellite    18.0         8
# 4              AMC Rebel SST    16.0         8
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[3])
df.insert(3,'Displacement',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement  \
# 0                     STRING  DOUBLE       INT       DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0
# 2          Buick Skylark 320    15.0         8        350.0
# 3         Plymouth Satellite    18.0         8        318.0
# 4              AMC Rebel SST    16.0         8        304.0
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[4])
df.insert(4,'Horsepower',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[5])
df.insert(5,'Weight',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight  \
# 0  DOUBLE
# 1   3504.
# 2   3693.
# 3   3436.
# 4   3433.
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[6])
df.insert(6,'Acceleration',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration  \
# 0  DOUBLE       DOUBLE
# 1   3504.         12.0
# 2   3693.         11.5
# 3   3436.         11.0
# 4   3433.         12.0
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[7])
df.insert(7,'Model',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model  \
# 0  DOUBLE       DOUBLE   INT
# 1   3504.         12.0    70
# 2   3693.         11.5    70
# 3   3436.         11.0    70
# 4   3433.         12.0    70
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4  AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %%
b = df['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'].apply(lambda x:x.split(';')[8])
df.insert(8,'Origin',b)
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin  \
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US
#
#   Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0  STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1  Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2  Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3  Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# ...

# %%
df.drop(['Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
df.drop(labels=0,axis=0,inplace=True)

# %%
df
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
df.size
# Out:
# 3654

# %%
df.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
len(df)
# Out:
# 406

# %%
df.shape
# Out:
# (406, 9)

# %%
df.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
df.describe()
# Out:
#                    Car   MPG Cylinders Displacement Horsepower Weight  \
# count              406   406       406          406        406    406
# unique             308   130         5           83         94    356
# top     Toyota Corolla  13.0         4        97.00      150.0  1985.
# freq                 9    20       207           22         22      4
#
#        Acceleration Model Origin
# count           406   406    406
# unique           97    13      3
# top            14.5    73     US
# freq             23    40    254

# %%
df.describe(include = "all")
# Out:
#                    Car   MPG Cylinders Displacement Horsepower Weight  \
# count              406   406       406          406        406    406
# unique             308   130         5           83         94    356
# top     Toyota Corolla  13.0         4        97.00      150.0  1985.
# freq                 9    20       207           22         22      4
#
#        Acceleration Model Origin
# count           406   406    406
# unique           97    13      3
# top            14.5    73     US
# freq             23    40    254

# %%
df.Weight.describe()
# Out:
# count       406
# unique      356
# top       1985.
# freq          4
# Name: Weight, dtype: object

# %%
df[df['Weight'] == '3693.']['Car']
# Out:
# 2    Buick Skylark 320
# Name: Car, dtype: object

# %%
df.isna().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %%
df.Car.value_counts()
# Out:
# Toyota Corolla          9
# Ford Pinto              6
# Volkswagen Rabbit       5
# AMC Matador             5
# Ford Maverick           5
#                        ..
# Mazda GLC               1
# Datsun B210 GX          1
# Toyota Tercel           1
# Mazda GLC 4             1
# Fiat 124 Sport Coupe    1
# Name: Car, Length: 308, dtype: int64

# %%
df.head()
# Out:
#                          Car   MPG Cylinders Displacement Horsepower Weight  \
# 1  Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2          Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3         Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4              AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                Ford Torino  17.0         8        302.0      140.0  3449.
#
#   Acceleration Model Origin
# 1         12.0    70     US
# 2         11.5    70     US
# 3         11.0    70     US
# 4         12.0    70     US
# 5         10.5    70     US

# %% [markdown]
# # Convert data types to proper format

# %%
df.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
df[["Cylinders","Model","MPG","Displacement","Horsepower","Acceleration","Weight"]] = df[["Cylinders","Model","MPG","Displacement","Horsepower","Acceleration","Weight"]].astype("float")

# %%
df.dtypes
# Out:
# Car              object
# MPG             float64
# Cylinders       float64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model           float64
# Origin           object
# dtype: object

# %%
df.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.735563     -0.764277   -0.726670 -0.787510
# Cylinders    -0.735563   1.000000      0.951787    0.823467  0.895220
# Displacement -0.764277   0.951787      1.000000    0.873758  0.932475
# Horsepower   -0.726670   0.823467      0.873758    1.000000  0.840811
# Weight       -0.787510   0.895220      0.932475    0.840811  1.000000
# Acceleration  0.424490  -0.522452     -0.557984   -0.682047 -0.430086
# Model         0.586234  -0.360762     -0.381714   -0.419929 -0.315389
#
#               Acceleration     Model
# MPG               0.424490  0.586234
# Cylinders        -0.522452 -0.360762
# Displacement     -0.557984 -0.381714
# Horsepower       -0.682047 -0.419929
# Weight           -0.430086 -0.315389
# Acceleration      1.000000  0.301992
# Model             0.301992  1.000000

# %%
df.Car.nunique()
# Out:
# 308

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 1  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 2          Buick Skylark 320  15.0        8.0         350.0       165.0
# 3         Plymouth Satellite  18.0        8.0         318.0       150.0
# 4              AMC Rebel SST  16.0        8.0         304.0       150.0
# 5                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 1  3504.0          12.0   70.0     US
# 2  3693.0          11.5   70.0     US
# 3  3436.0          11.0   70.0     US
# 4  3433.0          12.0   70.0     US
# 5  3449.0          10.5   70.0     US

# %% [markdown]
# # To Find counts of cars origin.

# %%
df[['Origin','Car']].value_counts()
# Out:
# Origin  Car
# Japan   Toyota Corolla             9
# US      Ford Pinto                 6
#         Ford Maverick              5
# Europe  Volkswagen Rabbit          5
# US      AMC Matador                5
#                                   ..
# Japan   Toyota Tercel              1
# US      AMC Ambassador Brougham    1
#         AMC Ambassador DPL         1
#         AMC Ambassador SST         1
#         Pontiac Ventura SJ         1
# Length: 308, dtype: int64

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 1  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 2          Buick Skylark 320  15.0        8.0         350.0       165.0
# 3         Plymouth Satellite  18.0        8.0         318.0       150.0
# 4              AMC Rebel SST  16.0        8.0         304.0       150.0
# 5                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 1  3504.0          12.0   70.0     US
# 2  3693.0          11.5   70.0     US
# 3  3436.0          11.0   70.0     US
# 4  3433.0          12.0   70.0     US
# 5  3449.0          10.5   70.0     US

# %%
import seaborn as sns

# %%
sns.countplot(df.MPG)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MPG', ylabel='count'>

# %%
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 1  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 2          Buick Skylark 320  15.0        8.0         350.0       165.0
# 3         Plymouth Satellite  18.0        8.0         318.0       150.0
# 4              AMC Rebel SST  16.0        8.0         304.0       150.0
# 5                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 1  3504.0          12.0   70.0     US
# 2  3693.0          11.5   70.0     US
# 3  3436.0          11.0   70.0     US
# 4  3433.0          12.0   70.0     US
# 5  3449.0          10.5   70.0     US

# %%
df.groupby('Horsepower').min()
# Out:
#                                      Car   MPG  Cylinders  Displacement  \
# Horsepower
# 0.0                       AMC Concord DL  21.0        4.0          85.0
# 46.0        Volkswagen 1131 Deluxe Sedan  26.0        4.0          97.0
# 48.0          Volkswagen Dasher (diesel)   0.0        4.0          90.0
# 49.0                            Fiat 128  29.0        4.0          68.0
# 52.0                  Chevrolet Chevette  29.0        4.0          76.0
# ...                                  ...   ...        ...           ...
# 210.0                         Dodge D200  11.0        8.0         318.0
# 215.0       Chrysler New Yorker Brougham  10.0        8.0         360.0
# 220.0                   Chevrolet Impala  14.0        8.0         454.0
# 225.0           Buick Electra 225 Custom  12.0        8.0         455.0
# 230.0                 Pontiac Grand Prix  16.0        8.0         400.0
#
#             Weight  Acceleration  Model  Origin
# Horsepower
# ...

# %%
df.groupby('Origin').count()
# Out:
#         Car  MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# Origin
# Europe   73   73         73            73          73      73            73
# Japan    79   79         79            79          79      79            79
# US      254  254        254           254         254     254           254
#
#         Model
# Origin
# Europe     73
# Japan      79
# US        254

# %%
df[~(df ==0).all(axis=1)]
