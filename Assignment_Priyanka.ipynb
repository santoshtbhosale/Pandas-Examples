# %% [markdown]
# # Work on the give dataset..find out the insights from data add your own analysis too

# %% [markdown]
# # IMPORTING DATA

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read data

# %%
df = pd.read_csv('Data priyanka.csv')
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# 2. Number of rows
df.shape[0]
# Out:
# 195

# %%
# 3. See columns
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
# 4. Number of columns
df.shape[1]
# Out:
# 5

# %%
# 5. Top Rows
df.iloc[0:5]
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# 6 Bottom rows
df.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# 7. Information on the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# 8. Get stats on the columns
df.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %% [markdown]
# ### Remove the space present in  Column names of a Dataframe and update it

# %%
df.columns.str.replace(' ','')
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %% [markdown]
# # SUBSETTING DATAFRAMES IN PANDAS
# Three Parts
# 1. Rows
# 2. Columns
# 3. Combine the two

# %% [markdown]
# ### Part 1: Subsetting Rows

# %%
# Fetch row Starting at index 185 to the end
df.iloc[185:]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
#fetch row from 100 to 150 and columns BirthRate	 CountryCode	 IncomeGroup-> InternetUsers
df.iloc[100:150][['Birth rate','Country Code','Income Group','Internet users']]
# Out:
#      Birth rate Country Code         Income Group  Internet users
# 100      21.425          LBY  Upper middle income         16.5000
# 101      15.430          LCA  Upper middle income         46.2000
# 102       9.200          LIE          High income         93.8000
# 103      17.863          LKA  Lower middle income         21.9000
# 104      28.738          LSO  Lower middle income          5.0000
# 105      10.100          LTU          High income         68.4529
# 106      11.300          LUX          High income         93.7765
# 107      10.200          LVA          High income         75.2344
# 108      11.256          MAC          High income         65.8000
# 109      21.023          MAR  Lower middle income         56.0000
# 110      12.141          MDA  Lower middle income         45.0000
# 111      34.686          MDG           Low income          3.0000
# 112      21.447          MDV  Upper middle income         44.1000
# ...

# %%
# Reverse the dataframe
df.iloc[::-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group  new column
# 194           Low income    660.7275
# 193  Lower middle income    623.2534
# 192           Low income     93.2668
# ...

# %%
# Get ONLY every 20th row: means row present at index 0-20-40-60
df.iloc[::20]
# Out:
#     Country Name Country Code  Birth rate  Internet users  \
# 0          Aruba          ABW      10.244         78.9000
# 20       Belarus          BLR      12.500         54.1700
# 40    Costa Rica          CRI      15.022         45.9600
# 60         Gabon          GAB      30.555          9.2000
# 80         India          IND      20.291         15.1000
# 100        Libya          LBY      21.425         16.5000
# 120   Mozambique          MOZ      39.705          5.4000
# 140       Poland          POL       9.600         62.8492
# 160     Suriname          SUR      18.455         37.4000
# 180      Uruguay          URY      14.374         57.6900
#
#             Income Group  new column
# 0            High income   808.25160
# 20   Upper middle income   677.12500
# 40   Upper middle income   690.41112
# 60   Upper middle income   281.10600
# 80   Lower middle income   306.39410
# 100  Upper middle income   353.51250
# 120           Low income   214.40700
# ...

# %% [markdown]
# ### Part 2: Subsetting Columns

# %%
# Subset one column 'CountryName'
df['Country Name']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: Country Name, Length: 195, dtype: object

# %%
# Subset multiple columns 'CountryName','BirthRate'
df[['Country Name','Birth rate']]
# Out:
#              Country Name  Birth rate
# 0                   Aruba      10.244
# 1             Afghanistan      35.253
# 2                  Angola      45.985
# 3                 Albania      12.877
# 4    United Arab Emirates      11.044
# ..                    ...         ...
# 190           Yemen, Rep.      32.947
# 191          South Africa      20.850
# 192      Congo, Dem. Rep.      42.394
# 193                Zambia      40.471
# 194              Zimbabwe      35.715
#
# [195 rows x 2 columns]

# %% [markdown]
# # BASIC OPERATIONS WITH A DATAFRAME

# %% [markdown]
# ### Mathmatical Operations

# %%
# Mathmatical Operations: 
#do the multiplication of BirthRate & InternetUsers and create a new column to store it in dataframe
df['new column'] = df['Birth rate'] * df['Internet users']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-874c894a95c8> in <module>
# ----> 1 df['new col'] = df['Birth rate'] == 5.9
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group  new column
# 0            High income    808.2516
# 1             Low income    207.9927
# 2    Upper middle income    878.3135
# ...

# %%
# Removing a column 'MyCalc'

# %% [markdown]
# # FILTERING DATAFRAMES

# %%
#Filtering is about rows where 'InternetUsers' less than 2
df[df['Internet users'] < 2]
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group  new column
# 11            Low income     57.3963
# 52            Low income     31.3200
# 55            Low income     62.5575
# 64            Low income     59.7392
# 117  Lower middle income     28.9904
# 127           Low income     84.4237
# 154           Low income     62.4393
# 156           Low income     65.8365
# ...

# %%
# Filter by birthrate greater than 40
df[df['Birth rate'] > 40]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group  new column
# 2    Upper middle income    878.3135
# 11            Low income     57.3963
# ...

# %%
# Filter for high income countries
df[df['Income Group'] == 'High income']['Country Name']
# Out:
# 0                      Aruba
# 4       United Arab Emirates
# 5                  Argentina
# 7        Antigua and Barbuda
# 8                  Australia
#                ...
# 174      Trinidad and Tobago
# 180                  Uruguay
# 181            United States
# 184            Venezuela, RB
# 185    Virgin Islands (U.S.)
# Name: Country Name, Length: 67, dtype: object

# %%
#  get unique categories of income group
df['Income Group'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# Find out everything about Malta
df[df['Country Name'] == 'Malta']
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group  \
# 116        Malta          MLT         9.5         68.9138  High income
#
#      new column
# 116    654.6811
